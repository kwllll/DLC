# %%
import pandas as pd

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql+psycopg2://postgres:311705@localhost/others")

# %%
df = pd.read_csv("https://online-price-watch.consumer.org.hk/opw/opendata/pricewatch_zh-Hant.csv")
df['stock_name'] = df['品牌'] + ' - ' + df['貨品名稱']
print(df.shape)

df_na = df[df['優惠'].isna()]
df_na['price_discount'] = df_na['價格'].astype(str)
df_not_na = df[~(df['優惠'].isna())]
df_not_na['price_discount'] = df_not_na['價格'].astype(str) + ' (' + df_not_na['優惠'] + ')'
print(df_na.shape)
print(df_not_na.shape)

df = pd.concat([df_na, df_not_na], ignore_index = False)
print(df.shape)

df = df.fillna("-")
# Out:
# (6567, 10)
# (4374, 11)
# (2193, 11)
# (6567, 11)
# C:\Users\kwan_\AppData\Local\Temp\ipykernel_18212\4004871694.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_na['price_discount'] = df_na['價格'].astype(str)
# C:\Users\kwan_\AppData\Local\Temp\ipykernel_18212\4004871694.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_not_na['price_discount'] = df_not_na['價格'].astype(str) + ' (' + df_not_na['優惠'] + ')'

# %%
table_name = 'dlc_daily_product_price'
df.to_sql(table_name, engine, if_exists = 'replace', index = False)
# Out:
# 567

# %%
df[df['貨品名稱'] == '(米王之皇) 紅米 1.5公斤']
# Out:
#                       貨品分類1 貨品分類2          貨品分類3        貨品編號        品牌  \
# 1577  米 / 食油 / 罐頭 / 蔬果 / 肉類     米  紅米 / 糙米 / 混合米  P000001062  金鳳 (鉅發源)
#
#                  貨品名稱       超市代號    價格 優惠                  stock_name  \
# 1577  (米王之皇) 紅米 1.5公斤  PARKNSHOP  50.0  -  金鳳 (鉅發源) - (米王之皇) 紅米 1.5公斤
#
#      price_discount
# 1577           50.0

# %%
df['超市代號'].unique()
# Out:
# array(['WELLCOME', 'PARKNSHOP', 'JASONS', 'AEON', 'LUNGFUNG', 'WATSONS',
#        'MANNINGS', 'DCHFOOD', 'SASA'], dtype=object)

# %%
if 'shop_list_deafult_text' not in st.session_state:
    st.session_state.shop_list_deafult_text = ['Parknshop', 'Wellcome']

if 'cat1_deafult_text' not in st.session_state:
    st.session_state.cat1_deafult_text = 0

if 'cat2_deafult_text' not in st.session_state:
    st.session_state.cat2_deafult_text = 0
